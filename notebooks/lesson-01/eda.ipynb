# %% [markdown]
# # Lesson 01 — Churn come classificazione: EDA
#
# Notebook di lavoro (scheletro).

# %% [markdown]
# ## Obiettivo
# (TODO) Definire il problema e fare una prima analisi esplorativa.

# %% [markdown]
# ## Parte teorica (outline)
# - (TODO) Churn e target
# - (TODO) Feature disponibili e qualità del dato
# - (TODO) Rischi: leakage, sbilanciamento

# %% [markdown]
# ## Parte pratica
# ### Caricamento e ispezione

# %%
# TODO: import necessari
# TODO: caricare i dati (path/placeholder)

# import pandas as pd

# %% [markdown]
# ### EDA essenziale

# %%
# TODO: statistiche descrittive
# TODO: distribuzione target e feature principali
# TODO: missing values e outlier (placeholder)

# %% [markdown]
# ### Baseline (placeholder)

# %%
# TODO: split train/test
# TODO: baseline semplice (senza tuning)
# TODO: prima metrica (es. ROC-AUC)
