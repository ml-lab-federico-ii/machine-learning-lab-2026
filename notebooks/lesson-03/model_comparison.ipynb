# %% [markdown]
# # Lesson 03 — Confronto modelli e metriche
#
# Notebook di lavoro (scheletro).

# %% [markdown]
# ## Obiettivo
# (TODO) Addestrare più modelli e confrontarli con metriche coerenti.

# %% [markdown]
# ## Parte teorica (outline)
# - (TODO) Confusion matrix e metriche
# - (TODO) ROC e ROC-AUC
# - (TODO) Cross-validation

# %% [markdown]
# ## Parte pratica
# ### Setup pipeline + modelli

# %%
# TODO: import e caricamento dati (placeholder)
# TODO: recuperare pipeline preprocessing
# TODO: definire modelli da confrontare

# %% [markdown]
# ### Valutazione e confronto

# %%
# TODO: cross-validation (placeholder)
# TODO: calcolo ROC-AUC e altre metriche
# TODO: tabella di confronto
