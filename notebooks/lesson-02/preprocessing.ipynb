# %% [markdown]
# # Lesson 02 — Preprocessing e pipeline
#
# Notebook di lavoro (scheletro).

# %% [markdown]
# ## Obiettivo
# (TODO) Trasformare il dato grezzo in un dataset modellabile e riproducibile.

# %% [markdown]
# ## Parte teorica (outline)
# - (TODO) Missing values
# - (TODO) Encoding categoriche
# - (TODO) Scaling numeriche
# - (TODO) Pipeline e leakage

# %% [markdown]
# ## Parte pratica
# ### Definizione colonne e trasformazioni

# %%
# TODO: import necessari
# TODO: caricare dati (placeholder)
# TODO: definire colonne numeriche/categoriche

# %% [markdown]
# ### Pipeline scikit-learn

# %%
# TODO: costruire ColumnTransformer + Pipeline
# TODO: fit/transform su train, transform su test
