# %% [markdown]
# # Lesson 04 — Feature importance e interpretabilità
#
# Notebook di lavoro (scheletro).

# %% [markdown]
# ## Obiettivo
# (TODO) Analizzare l’importanza delle feature e interpretare il modello.

# %% [markdown]
# ## Parte teorica (outline)
# - (TODO) Importanza globale vs locale
# - (TODO) Permutation importance
# - (TODO) Limiti dell’interpretazione

# %% [markdown]
# ## Parte pratica
# ### Addestramento modello candidato

# %%
# TODO: import e caricamento dati (placeholder)
# TODO: addestrare/ricaricare il modello candidato

# %% [markdown]
# ### Feature importance

# %%
# TODO: calcolare feature importance (model-based)
# TODO: permutation importance (placeholder)
# TODO: grafici e commento (placeholder)
