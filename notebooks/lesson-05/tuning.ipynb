# %% [markdown]
# # Lesson 05 — Tuning e workflow di progetto
#
# Notebook di lavoro (scheletro).

# %% [markdown]
# ## Obiettivo
# (TODO) Impostare un tuning minimale e generare una submission per la challenge.

# %% [markdown]
# ## Parte teorica (outline)
# - (TODO) Scelta metrica e schema di CV
# - (TODO) Hyperparameter tuning
# - (TODO) Reproducibilità e consegna

# %% [markdown]
# ## Parte pratica
# ### Ricerca iperparametri (placeholder)

# %%
# TODO: import e caricamento dati (placeholder)
# TODO: definire pipeline (preprocessing + modello)
# TODO: definire spazio iperparametri

# %% [markdown]
# ### Submission (placeholder)

# %%
# TODO: addestrare modello finale
# TODO: generare predizioni di probabilità
# TODO: salvare CSV con colonne: id, churn_probability
